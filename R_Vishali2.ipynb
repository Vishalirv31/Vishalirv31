# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishalirv31/Vishalirv31/blob/Assignment/R_Vishali2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preprocessing the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data =pd.read_csv('/House Price India.csv')

# %%
data
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[data.columns] = scaler.fit_transform(data[data.columns])

# %%
from sklearn.model_selection import train_test_split
x=data.drop(['Price'],axis=1)
y=data['Price']
x_train,x_test, y_train,y_test =  train_test_split(x,y, test_size=0.2,random_state=42)

# %% [markdown]
# Building ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

# Input layer
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))

# Hidden layers
model.add(Dense(10, activation='relu'))
model.add(Dense(5, activation='relu'))

# Output layer
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                460
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# ...
# Total params: 731
# Trainable params: 731
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Testing the model

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 293/293 [==============================] - 2s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0265 - val_loss: 7.8593e-04 - val_mean_absolute_error: 0.0173
# Epoch 2/100
# 293/293 [==============================] - 0s 2ms/step - loss: 8.0737e-04 - mean_absolute_error: 0.0166 - val_loss: 6.3454e-04 - val_mean_absolute_error: 0.0161
# Epoch 3/100
# 293/293 [==============================] - 0s 2ms/step - loss: 6.6449e-04 - mean_absolute_error: 0.0146 - val_loss: 5.0836e-04 - val_mean_absolute_error: 0.0133
# Epoch 4/100
# 293/293 [==============================] - 0s 2ms/step - loss: 5.6538e-04 - mean_absolute_error: 0.0131 - val_loss: 4.4757e-04 - val_mean_absolute_error: 0.0123
# Epoch 5/100
# 293/293 [==============================] - 1s 2ms/step - loss: 5.0336e-04 - mean_absolute_error: 0.0121 - val_loss: 4.1883e-04 - val_mean_absolute_error: 0.0117
# Epoch 6/100
# ...

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 366/366 [==============================] - 2s 2ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 2/100
# 366/366 [==============================] - 1s 2ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 3/100
# 366/366 [==============================] - 1s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 4/100
# 366/366 [==============================] - 1s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 5/100
# 366/366 [==============================] - 1s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 6/100
# 366/366 [==============================] - 1s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 7/100
# 366/366 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 8/100
# 366/366 [==============================] - 1s 1ms/step - loss: 0.2131 - accuracy: 1.7100e-04
# Epoch 9/100
# 366/366 [==============================] - 0s 1ms/step - loss: 0.2132 - accuracy: 1.7100e-04
# Epoch 10/100
# ...

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)
# Out:
# ...
# 92/92 [==============================] - 0s 1ms/step

# %%
#mean squared error

# %%
import numpy as np
train_mse = np.mean((y_train - y_train_pred.flatten())**2)
test_mse = np.mean((y_test - y_test_pred.flatten())**2)
print("Mean Squared Error for training data : ",train_mse)
print("Mean Squared Error for testing data : ",test_mse)
# Out:
# Mean Squared Error for training data :  1.017557887504991e-05
# Mean Squared Error for testing data :  3.206446920067008e-05

# %%
#root mean squared error

# %%
import math
train_rmse = math.sqrt(train_mse)
test_rmse = math.sqrt(test_mse)
print("Root Mean Squared Error for training data : ",train_rmse)
print("Root Mean Squared Error for testing data : ",test_rmse)
# Out:
# Root Mean Squared Error for training data :  0.0031899183179275783
# Root Mean Squared Error for testing data :  0.005662549708450256

# %%
#mean absolute value

# %%
from sklearn.metrics import mean_absolute_error
train_mae = mean_absolute_error(y_train, y_train_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)
print("Mean Absolute Error for training data : ",train_mae)
print("Mean Absolute Error for testing data : ",test_mae)
# Out:
# Mean Absolute Error for training data :  0.0013604191110837165
# Mean Absolute Error for testing data :  0.0016349531488051734

# %%
#R-squared value

# %%
from sklearn.metrics import r2_score
train_r2 = r2_score(y_train,y_train_pred)
test_r2 = r2_score(y_test,y_test_pred)
print("R-squared Score for training data : ",train_r2)
print("R-squared Score for testing data : ",test_r2)
# Out:
# R-squared Score for training data :  0.9955753037301254
# R-squared Score for testing data :  0.9867811844016509

# %%
#variance score

# %%
from sklearn.metrics import explained_variance_score

train_evs = explained_variance_score(y_train,y_train_pred)
test_evs = explained_variance_score(y_test,y_test_pred)
print(" Variance Score for train data : ",train_evs)
print(" Variance Score for test data : ",test_evs)
# Out:
#  Variance Score for train data :  0.9957679192992703
#  Variance Score for test data :  0.9870204149517363
